# %% [markdown]
# # My Spotify Data
# Here is my Spotify streaming data and my 2024 Wrapped data. <br>
# My sister gave me permission to use her data as well. I am still waiting for spotify to send her the data she requested through her account. <br>
#
# Both of these data sets are json files downloaded from spotify.

# %%
import json as js
import pandas as pd

# %%
# My streaming data
path = r"/Users/ellabenore/Downloads/Spotify Account Data/StreamingHistory_music_1.json"

with open(path) as op:
    data1 = js.load(op)

# My 2024 Wrapped
path = r"/Users/ellabenore/Downloads/Spotify Account Data/Wrapped2024.json"

with open(path) as op:
    data2 = js.load(op)

# %%
type(data1)
# Out:
# list

# %%
type(data2)
# Out:
# dict

# %%
data2.keys()
# Out:
# dict_keys(['topArtists', 'topPodcasts', 'topTracks', 'yearlyMetrics', 'musicEvolution'])
